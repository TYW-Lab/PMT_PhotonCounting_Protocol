# %% [markdown]
# # Code for controlling laser and oscilloscope

# %% [markdown]
# ## Initialization

# %%
import pyvisa
import time
import numpy as np
import time

# %%
SCOPE_IP = "10.210.30.243"

def connect_scope():
    """
    Connect to Rigol DHO4404 oscilloscope.
    Returns a PyVISA instrument object.
    """

    rm = pyvisa.ResourceManager("@py")

    scope = rm.open_resource(
        f"TCPIP0::{SCOPE_IP}::INSTR"
    )

    scope.timeout = 10000  # ms

    idn = scope.query("*IDN?").strip()

    print(f"Connected: {idn}")

    return scope

# %%
import time
import numpy as np


def acquire_waveform(scope, channel="CHAN1"):

    # Stop acquisition
    scope.write(":STOP")

    time.sleep(0.2)

    # Configure waveform transfer
    scope.write(f":WAV:SOUR {channel}")
    scope.write(":WAV:MODE RAW")
    scope.write(":WAV:FORM BYTE")

    # Scaling factors
    y_inc = float(scope.query(":WAV:YINC?"))
    y_org = float(scope.query(":WAV:YOR?"))
    y_ref = float(scope.query(":WAV:YREF?"))

    x_inc = float(scope.query(":WAV:XINC?"))
    x_org = float(scope.query(":WAV:XOR?"))

    sample_rate = 1.0 / x_inc

    print(f"x_inc = {x_inc:.3e} s")
    print(f"sample rate = {sample_rate/1e6:.2f} MSa/s")

    raw = scope.query_binary_values(
        ":WAV:DATA?",
        datatype="B",
        container=np.array
    )

    print("Downloaded points:", len(raw))

    if len(raw) == 0:

        scope.write(":RUN")

        raise RuntimeError(
            "Scope returned empty waveform."
        )

    voltage = (
        (raw.astype(np.float64) - y_ref)
        * y_inc
        + y_org
    )

    time_axis = (
        np.arange(len(voltage))
        * x_inc
        + x_org
    )

    acquisition_time = len(voltage) / sample_rate

    print(
        f"Acquisition length = "
        f"{acquisition_time:.6f} s"
    )

    # Resume acquisition
    scope.write(":RUN")

    time.sleep(1.2)

    return {
        "signal": voltage,
        "time": time_axis,
        "sample_rate": sample_rate,
        "acquisition_time": acquisition_time,
        "channel": channel,
    }

# %%
scope = connect_scope()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 scope = connect_scope()
#
# Cell In[8], line 11, in connect_scope()
#       7     """
#       8
#       9     rm = pyvisa.ResourceManager("@py")
#      10
# ---> 11     scope = rm.open_resource(
#      12         f"TCPIP0::{SCOPE_IP}::INSTR"
#      13     )
#      14
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/highlevel.py:3302, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3296     if not present:
#    3297         raise ValueError(
#    3298             "%r is not a valid attribute for type %s"
#    3299             % (key, res.__class__.__name__)
#    3300         )
# -> 3302 res.open(access_mode, open_timeout)
#    3304 for key, value in kwargs.items():
#    3305     setattr(res, key, value)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/resources/resource.py:290, in Resource.open(self, access_mode, open_timeout)
#     286 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     287 with self._resource_manager.ignore_warning(
#     288     constants.StatusCode.success_device_not_present
#     289 ):
# --> 290     self.session, status = self._resource_manager.open_bare_resource(
#     291         self._resource_name, access_mode, open_timeout
#     292     )
#     294     if status == constants.StatusCode.success_device_not_present:
#     295         # The device was not ready when we opened the session.
#     296         # Now it gets five seconds more to become ready.
#     297         # Every 0.1 seconds we probe it with viClear.
#     298         start_time = time.time()
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/highlevel.py:3227, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3198 def open_bare_resource(
#    3199     self,
#    3200     resource_name: str,
#    3201     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3202     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3203 ) -> Tuple[VISASession, StatusCode]:
#    3204     """Open the specified resource without wrapping into a class.
#    3205
#    3206     Parameters
#    (...)   3225
#    3226     """
# -> 3227     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/highlevel.py:196, in PyVisaLibrary.open(self, session, resource_name, access_mode, open_timeout)
#     191 cls = Session.get_session_class(
#     192     parsed.interface_type_const, parsed.resource_class
#     193 )
#     195 try:
# --> 196     sess = cls(session, resource_name, parsed, open_timeout)
#     197 except OpenError as e:
#     198     return VISASession(0), self.handle_return_value(None, e.error_code)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/tcpip.py:86, in TCPIPInstrSession.__new__(cls, resource_manager_session, resource_name, parsed, open_timeout)
#      83 else:
#      84     newcls = TCPIPInstrVxi11
# ---> 86 return newcls(resource_manager_session, resource_name, parsed, open_timeout)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/sessions.py:329, in Session.__init__(self, resource_manager_session, resource_name, parsed, open_timeout)
#     326 default_timeout = attributes.AttributesByID[attr].default
#     327 self.set_attribute(attr, default_timeout)
# --> 329 self.after_parsing()
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/tcpip.py:506, in TCPIPInstrVxi11.after_parsing(self)
#     501 error, link, abort_port, max_recv_size = self.interface.create_link(
#     502     self.client_id, 0, self.lock_timeout, self.parsed.lan_device_name
#     503 )
#     505 if error:
# --> 506     raise Exception("error creating link: %d" % error)
#     508 self.link = link
#     509 self.max_recv_size = min(max_recv_size, 2**30)  # 1GB
#
# Exception: error creating link: 9

# %%
import pyvisa

rm = pyvisa.ResourceManager("@py")

scope = rm.open_resource(
    "TCPIP0::10.210.30.243::hislip0::INSTR"
)

print(scope.query("*IDN?"))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/tcpip.py:140, in TCPIPInstrHiSLIP.after_parsing(self)
#     139 try:
# --> 140     self.interface = hislip.Instrument(
#     141         self.parsed.host_address,
#     142         open_timeout=(
#     143             self.open_timeout * 1000.0
#     144             if self.open_timeout is not None
#     145             else self.open_timeout
#     146         ),
#     147         timeout=self.timeout,
#     148         port=port,
#     149         sub_address=sub_address,
#     150     )
#     151 except Exception as e:
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/protocols/hislip.py:391, in Instrument.__init__(self, ip_addr, open_timeout, timeout, port, sub_address)
#     390 self._sync.settimeout(5.0)
# --> 391 self._sync.connect((ip_addr, port))
#     392 self._sync.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# OpenError                                 Traceback (most recent call last)
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/highlevel.py:196, in PyVisaLibrary.open(self, session, resource_name, access_mode, open_timeout)
#     195 try:
# --> 196     sess = cls(session, resource_name, parsed, open_timeout)
#     197 except OpenError as e:
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/tcpip.py:86, in TCPIPInstrSession.__new__(cls, resource_manager_session, resource_name, parsed, open_timeout)
#      84     newcls = TCPIPInstrVxi11
# ---> 86 return newcls(resource_manager_session, resource_name, parsed, open_timeout)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/sessions.py:329, in Session.__init__(self, resource_manager_session, resource_name, parsed, open_timeout)
#     327 self.set_attribute(attr, default_timeout)
# --> 329 self.after_parsing()
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/tcpip.py:156, in TCPIPInstrHiSLIP.after_parsing(self)
#     152     LOGGER.exception(
#     153         f"Failed to open HiSLIP connection to {self.parsed.host_address} "
#     154         f"on port {port} with lan device name {sub_address}"
#     155     )
# --> 156     raise OpenError() from e
#     158 # initialize the constant attributes
#
# OpenError:
#
# During handling of the above exception, another exception occurred:
#
# VisaIOError                               Traceback (most recent call last)
# Cell In[11], line 5
#       1 import pyvisa
#       2
#       3 rm = pyvisa.ResourceManager("@py")
#       4
# ----> 5 scope = rm.open_resource(
#       6     "TCPIP0::10.210.30.243::hislip0::INSTR"
#       7 )
#       8
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/highlevel.py:3302, in ResourceManager.open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    3296     if not present:
#    3297         raise ValueError(
#    3298             "%r is not a valid attribute for type %s"
#    3299             % (key, res.__class__.__name__)
#    3300         )
# -> 3302 res.open(access_mode, open_timeout)
#    3304 for key, value in kwargs.items():
#    3305     setattr(res, key, value)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/resources/resource.py:290, in Resource.open(self, access_mode, open_timeout)
#     286 logger.debug("%s - opening ...", self._resource_name, extra=self._logging_extra)
#     287 with self._resource_manager.ignore_warning(
#     288     constants.StatusCode.success_device_not_present
#     289 ):
# --> 290     self.session, status = self._resource_manager.open_bare_resource(
#     291         self._resource_name, access_mode, open_timeout
#     292     )
#     294     if status == constants.StatusCode.success_device_not_present:
#     295         # The device was not ready when we opened the session.
#     296         # Now it gets five seconds more to become ready.
#     297         # Every 0.1 seconds we probe it with viClear.
#     298         start_time = time.time()
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/highlevel.py:3227, in ResourceManager.open_bare_resource(self, resource_name, access_mode, open_timeout)
#    3198 def open_bare_resource(
#    3199     self,
#    3200     resource_name: str,
#    3201     access_mode: constants.AccessModes = constants.AccessModes.no_lock,
#    3202     open_timeout: int = constants.VI_TMO_IMMEDIATE,
#    3203 ) -> Tuple[VISASession, StatusCode]:
#    3204     """Open the specified resource without wrapping into a class.
#    3205
#    3206     Parameters
#    (...)   3225
#    3226     """
# -> 3227     return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa_py/highlevel.py:198, in PyVisaLibrary.open(self, session, resource_name, access_mode, open_timeout)
#     196     sess = cls(session, resource_name, parsed, open_timeout)
#     197 except OpenError as e:
# --> 198     return VISASession(0), self.handle_return_value(None, e.error_code)
#     200 return self._register(sess), StatusCode.success
#
# File /opt/miniconda3/envs/photoncounting/lib/python3.11/site-packages/pyvisa/highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_RSRC_NFOUND (-1073807343): Insufficient location information or the requested device or resource is not present in the system.

# %% [markdown]
# ### Data acquisition

# %%
from pathlib import Path

SAVE_FOLDER = Path("/Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=30mins/PMT=0.85")

SAVE_FOLDER.mkdir(exist_ok=True)

# %%
repeat = 10

for i in range(repeat):

    print(f"Waiting for trigger {i+1}/{repeat}")

    waveform = acquire_waveform(
        scope,
        channel="CHAN1"
    )

    filename = SAVE_FOLDER / f"data_{i+1:03d}.npz"

    np.savez(
        filename,
        signal=waveform["signal"],
        sample_rate=waveform["sample_rate"],
        acquisition_time=waveform["acquisition_time"],
        channel=waveform["channel"]
    )

    print(f"Saved: {filename}")
# Out:
# Waiting for trigger 1/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_001.npz
# Waiting for trigger 2/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_002.npz
# Waiting for trigger 3/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_003.npz
# Waiting for trigger 4/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_004.npz
# Waiting for trigger 5/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_005.npz
# Waiting for trigger 6/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_006.npz
# Waiting for trigger 7/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_007.npz
# Waiting for trigger 8/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_008.npz
# Waiting for trigger 9/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_009.npz
# Waiting for trigger 10/10
# x_inc = 1.000e-07 s
# sample rate = 10.00 MSa/s
# Downloaded points: 10000000
# Acquisition length = 1.000000 s
# Saved: /Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=15mins/PMT=0/data_010.npz

# %%
import numpy as np
import matplotlib.pyplot as plt

file = "/Users/zipeiwu/Desktop/BU/lab/projects/imaging/single_photon_counting/scope/notrigger/20260605_setup_time/t=0/PMT=0.85/data_001.npz"

data = np.load(file)

signal = data["signal"]
sample_rate = float(data["sample_rate"])

time = np.arange(len(signal)) / sample_rate

plt.figure(figsize=(10,4))
plt.plot(time * 1e6, signal)
plt.ylim(-0.1, 0)

plt.xlabel("Time (µs)")
plt.ylabel("Voltage (V)")
plt.title("PMT Waveform")
plt.tight_layout()

plt.show()

# %%
# !ping <SCOPE_IP>
# Out:
# zsh:1: parse error near `>'

# %%
# !ping 169.254.6.112
# Out:
# PING 169.254.6.112 (169.254.6.112): 56 data bytes
# Request timeout for icmp_seq 0
# Request timeout for icmp_seq 1
# Request timeout for icmp_seq 2
# Request timeout for icmp_seq 3
# ping: sendto: No route to host
# Request timeout for icmp_seq 4
# ping: sendto: Host is down
# Request timeout for icmp_seq 5
# ping: sendto: Host is down
# Request timeout for icmp_seq 6
# ping: sendto: Host is down
# Request timeout for icmp_seq 7
# ping: sendto: Host is down
# Request timeout for icmp_seq 8
# ping: sendto: Host is down
# Request timeout for icmp_seq 9
# ping: sendto: Host is down
# Request timeout for icmp_seq 10
# ping: sendto: Host is down
# Request timeout for icmp_seq 11
# ping: sendto: Host is down
# Request timeout for icmp_seq 12
# ping: sendto: Host is down
# Request timeout for icmp_seq 13
# ping: sendto: Host is down
# Request timeout for icmp_seq 14
# ping: sendto: Host is down
# Request timeout for icmp_seq 15
# ping: sendto: Host is down
# Request timeout for icmp_seq 16
# ping: sendto: Host is down
# Request timeout for icmp_seq 17
# ping: sendto: Host is down
# Request timeout for icmp_seq 18
# ping: sendto: Host is down
# Request timeout for icmp_seq 19
# ping: sendto: Host is down
# Request timeout for icmp_seq 20
# ping: sendto: Host is down
# Request timeout for icmp_seq 21
# ping: sendto: Host is down
# Request timeout for icmp_seq 22
# ^C
